# %%
import numpy as np
from itertools import chain
from collections import Counter

# %%
with open('data_input.txt') as f:
    input_lines = f.readlines()
input_lines[:10]
# Out:
# ['19394   30201\n',
#  '88523   40612\n',
#  '60736   82993\n',
#  '75224   92188\n',
#  '78157   27314\n',
#  '40925   54647\n',
#  '86284   23731\n',
#  '28269   14815\n',
#  '95540   16406\n',
#  '48998   59590\n']

# %%
input_lines = [a.replace('\n','') for a in input_lines ]
input_lines[:10]
# Out:
# ['19394   30201',
#  '88523   40612',
#  '60736   82993',
#  '75224   92188',
#  '78157   27314',
#  '40925   54647',
#  '86284   23731',
#  '28269   14815',
#  '95540   16406',
#  '48998   59590']

# %%
input_lines_split = [a.strip().split() for a in input_lines]
list(chain.from_iterable(input_lines_split))[::2]
list(chain.from_iterable(input_lines_split))[1::2]
# Out:
# ['30201',
#  '40612',
#  '82993',
#  '92188',
#  '27314',
#  '54647',
#  '23731',
#  '14815',
#  '16406',
#  '59590',
#  '22128',
#  '70353',
#  '51911',
#  '77153',
#  '12816',
#  '68004',
#  '32178',
#  '31048',
#  '51911',
#  '14440',
#  '18533',
#  '88299',
#  '56543',
#  '62539',
#  '55936',
#  '98934',
#  '33887',
#  '68649',
#  '45428',
#  '68630',
#  '79502',
#  '42203',
#  '54647',
#  '97148',
#  '14515',
#  '12813',
#  '45282',
#  '31585',
#  '68649',
#  '59959',
#  '80858',
#  '27250',
#  '14973',
#  '96725',
#  '16113',
#  '22128',
#  '51105',
#  '31929',
#  '28456',
#  '87150',
#  '38055',
#  '28210',
#  '41359',
#  '22128',
#  '53022',
#  '93317',
#  '80239',
#  '96253',
#  '59590',
#  '14515',
#  '81433',
#  '39312',
#  '36516',
#  '37518',
#  '73072',
#  '39440',
#  '38055',
#  '54647',
#  '39768',
#  '21222',
#  '22128',
#  '37518',
#  '93649',
#  '51911',
#  '69694',
#  '18529',
#  '42203',
#  '30201',
#  '80207',
#  '68004',
#  '42203',
#  '18611',
#  '52826',
# ...

# %%
list1 = sorted(list(chain.from_iterable(input_lines_split))[::2])
list2 = sorted(list(chain.from_iterable(input_lines_split))[1::2])

# %%
list2
# Out:
# ['10144',
#  '10146',
#  '10231',
#  '10317',
#  '10605',
#  '11201',
#  '11686',
#  '11930',
#  '12136',
#  '12189',
#  '12245',
#  '12245',
#  '12245',
#  '12245',
#  '12245',
#  '12366',
#  '12813',
#  '12814',
#  '12816',
#  '12864',
#  '13197',
#  '13326',
#  '13832',
#  '13993',
#  '14018',
#  '14052',
#  '14082',
#  '14100',
#  '14138',
#  '14273',
#  '14440',
#  '14481',
#  '14513',
#  '14515',
#  '14515',
#  '14515',
#  '14515',
#  '14515',
#  '14515',
#  '14515',
#  '14515',
#  '14515',
#  '14515',
#  '14515',
#  '14515',
#  '14515',
#  '14815',
#  '14973',
#  '15028',
#  '15344',
#  '15424',
#  '15455',
#  '15464',
#  '15723',
#  '15825',
#  '15919',
#  '16021',
#  '16055',
#  '16113',
#  '16311',
#  '16357',
#  '16406',
#  '16723',
#  '16830',
#  '16948',
#  '16964',
#  '17137',
#  '17400',
#  '17400',
#  '17400',
#  '17400',
#  '17400',
#  '17400',
#  '17400',
#  '17400',
#  '17400',
#  '17400',
#  '17400',
#  '17400',
#  '17400',
#  '17547',
#  '17669',
#  '17787',
# ...

# %%
sum([abs(int(a)-int(b)) for a,b in zip(list1,list2)])
# Out:
# 2742123

# %%
# Part 2
# are you working copilot puppy

#list2.count("10144")

sum([int(a)*list2.count(a) for a in list1])
# Out:
# 21328497
